# %% [markdown]
# <a href="https://colab.research.google.com/github/samarthmoree/Blender/blob/main/Cloth_Animation_blend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
blenderVersion = '3.2.2'
isBlenderUrl = False
isFileUrl = False
renderEngine = 'CYCLES'
renderer = 'CUDA'
startFrame = 1
endFrame = 100
audio = False
fileFormat = 'JPG'
logEnable = True
animation = True
token = 'eyJleHAiOiIyMDIyLTA4LTIxIDA3OjU5OjEzIn0='
outputPath = '/gdrive/My Drive/Blender/'
blenderFilePath = '/gdrive/My Drive/Blender/Cloth_Animation.blend'

# %%
import os

os.system('pip install git+https://github.com/metafylabs/metablenderrenderer.git#egg=metalabblender')
# Out:
# 0

# %%
from metalabblender import blender

blenderLib = blender.Blender(blenderFilePath, isFileUrl, outputPath, blenderVersion, isBlenderUrl, fileFormat, renderEngine, startFrame, endFrame, renderer, animation, audio, logEnable, token)
blenderLib.setup()
blenderLib.render()
# Out:
# Current GPU: Tesla T4
#
# Installing blender = 3.2.2
# Blender installed...3.2.2
# Setup completed
# starting to process blender...
# ./blender-3.2.2-linux-x64/blender -b /gdrive/My Drive/Blender/Cloth_Animation.blend -noaudio -E CYCLES --log-level 1 -o /gdrive/My Drive/Blender/ -s 1 -e 100 -F JPG -a -- --cycles-device CUDA
# b'Blender 3.2.2 (hash bcfdb14560e7 built 2022-08-02 23:38:01)\n'
# b'Read blend: /gdrive/My Drive/Blender/Cloth_Animation.blend\n'
# b'\n'
# b"Error: Format from '-F / --render-format' not known or not compiled in this release.\n"
# b'Fra:1 Mem:54.92M (Peak 55.31M) | Time:00:00.29 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | Cube\n'
# b'Fra:1 Mem:54.92M (Peak 55.31M) | Time:00:00.29 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | Outer cube\n'
# b'Fra:1 Mem:55.05M (Peak 55.55M) | Time:00:00.29 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | Plane\n'
# ...
